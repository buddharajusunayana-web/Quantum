# %% [markdown]
# <a href="https://colab.research.google.com/github/buddharajusunayana-web/Quantum/blob/main/Teleportation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit qiskit_aer pylatexenc matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister,ClassicalRegister
from qiskit_aer import AerSimulator

qc=QuantumCircuit(3,2)
qr=QuantumRegister(3)
cr=ClassicalRegister(3)
qc=QuantumCircuit(qr,cr)
qc.h(0)
qc.h(1)
qc.cx(1,2)

qc.cx(0,1)
qc.h(0)
qc.measure(qr[0],cr[0])
qc.measure(qr[1],cr[1])

with qc.if_test((cr[0],0)):
  qc.x(2)

with qc.if_test((cr[1],0)):
  qc.z(2)

qc.h(2)
qc.measure(qr[2], cr[2])

sim=AerSimulator()
result=sim.run(qc).result()
counts=result.get_counts()

print(counts)


qc.draw("mpl")
# Out:
# {'011': 272, '000': 244, '010': 256, '001': 252}
